# %%
# !pip install pywhatkit pandas
# Out:
# ...
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import pywhatkit as kit
import time

df = pd.read_excel("Sales_Persons.xlsx")

for i, row in df.iterrows():
    message = f"""
Dear {row['Name']},

Quotation Estimation Application Link: https://templearticles.com/
Your user credentials for login:
  - Emp ID: {row['Emp ID']}
  - Password: {row['Password']}

Application Tutorial Link: https://rajaspirituals-my.sharepoint.com/:v:/g/personal/analytics_rajaspiritual_com/IQBkqQ5vD0jFTIxpxBNHU4DsAZCiHBF2EpkFvVPWL62kZfo
"""

    phone = "+91" + str(row['Mobile'])
    
    kit.sendwhatmsg_instantly(phone, message, wait_time=15)
    time.sleep(3)
